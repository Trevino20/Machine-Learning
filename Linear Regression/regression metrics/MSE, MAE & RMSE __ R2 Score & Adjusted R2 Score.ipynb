# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
df.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]
data=pd.DataFrame([[1],[2],[3],[4],[5]])
data.ndim
x.ndim
# Out:
# 2

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train.values,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
y_pred = lr.predict(X_test)
y_test.values[:5]
# Out:
# array([[4.1 ],
#        [3.49],
#        [2.08],
#        [2.33],
#        [1.94]])

# %% [markdown]
# # MAE :- Mean Absolute Error

# %% [markdown]
# ![MAE.jpg](attachment:MAE.jpg)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2884710931878175

# %% [markdown]
# # MSE :- Mean Squared Error

# %% [markdown]
# ![19Cmk.gif](attachment:19Cmk.gif)

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12129235313495527

# %% [markdown]
# # RMSE :- Root Mean Squared Error

# %% [markdown]
# ![1_2WxU7C-XVLN1AiMJw24b_g.gif](attachment:1_2WxU7C-XVLN1AiMJw24b_g.gif)

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34827051717731616

# %% [markdown]
# # R2_Score

# %% [markdown]
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# ![img-2.jpg](attachment:img-2.jpg)

# %%
print("r2_Score",r2_score(y_test,y_pred))
# Out:
# r2_Score 0.780730147510384

# %% [markdown]
# # Adjusted R2 score

# %% [markdown]
# n :- total number of rows
# p :- total number of predict columns
# R2 : r2_score()

# %% [markdown]
# ![20181122142505520.png](attachment:20181122142505520.png)

# %%
r2 = r2_score(y_test,y_pred)

# %%
X_test.shape
# Out:
# (40, 1)

# %%
1 - ((1-r2)*(40-1)/(40-1-1))
# Out:
# 0.7749598882343415

# %% [markdown]
# # Why r2_score use

# %%
# adding random columns to the dataset
new_df1 = df.copy()
new_df1['random_feature'] = np.random.random(200)

new_df1 = new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.836346     3.26
# 1  5.12        0.454317     1.98
# 2  7.82        0.351969     3.25
# 3  7.42        0.949556     3.67
# 4  6.94        0.780788     3.57

# %%
# now see the plot
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %% [markdown]
# # Apply linear Regression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7824198249036007

# %%
y_test.shape
# Out:
# (40,)

# %%
X_test.shape
# Out:
# (40, 2)

# %%
1-((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7706587343578495

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]
new_df2.head()
# Out:
#    cgpa    iq  package
# 0  6.89  2.16     3.26
# 1  5.12  1.78     1.98
# 2  7.82  2.65     3.25
# 3  7.42  4.07     3.67
# 4  6.94  3.77     3.57

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.8630796673720914

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.8556785683111234
