# %%
import pandas as pd

# %% [markdown]
# # Working with json

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2023-03-28
# AFN  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ALL  https://www.exchangerate-api.com/terms  INR 2023-03-28
# AMD  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ANG  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2023-03-28
# YER  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ZAR  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ZMW  https://www.exchangerate-api.com/terms  INR 2023-03-28
# ZWL  https://www.exchangerate-api.com/terms  INR 2023-03-28
#
#      time_last_updated    rates
# AED         1679961602   0.0446
# AFN         1679961602   1.0500
# ALL         1679961602   1.2900
# AMD         1679961602   4.7200
# ANG         1679961602   0.0217
# ..                 ...      ...
# XPF         1679961602   1.3500
# YER         1679961602   3.0400
# ZAR         1679961602   0.2230
# ZMW         1679961602   0.2580
# ZWL         1679961602  11.1300
#
# [162 rows x 7 columns]

# %% [markdown]
# # Working with SQL

# %%
# !pip install mysql.connector
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247958 sha256=6df8f2d212a38cd7e51c4a78bfbdc9e2f3420ee19e4a0ff837ccab08c6c218ba
#   Stored in directory: c:\users\varva\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df=pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# C:\Users\varva\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
df2=pd.read_sql_query("SELECT * FROM city WHERE CountryCode='ARG'",conn)
# Out:
# C:\Users\varva\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df2
# Out:
#      ID                            Name CountryCode             District  \
# 0    69                    Buenos Aires         ARG     Distrito Federal
# 1    70                      La Matanza         ARG         Buenos Aires
# 2    71                         Córdoba         ARG              Córdoba
# 3    72                         Rosario         ARG             Santa Fé
# 4    73                 Lomas de Zamora         ARG         Buenos Aires
# 5    74                         Quilmes         ARG         Buenos Aires
# 6    75                 Almirante Brown         ARG         Buenos Aires
# 7    76                        La Plata         ARG         Buenos Aires
# 8    77                   Mar del Plata         ARG         Buenos Aires
# 9    78           San Miguel de Tucumán         ARG              Tucumán
# 10   79                           Lanús         ARG         Buenos Aires
# 11   80                           Merlo         ARG         Buenos Aires
# 12   81              General San Martín         ARG         Buenos Aires
# 13   82                           Salta         ARG                Salta
# 14   83                          Moreno         ARG         Buenos Aires
# 15   84                        Santa Fé         ARG             Santa Fé
# 16   85                      Avellaneda         ARG         Buenos Aires
# 17   86                 Tres de Febrero         ARG         Buenos Aires
# 18   87                           Morón         ARG         Buenos Aires
# 19   88                Florencio Varela         ARG         Buenos Aires
# 20   89                      San Isidro         ARG         Buenos Aires
# 21   90                           Tigre         ARG         Buenos Aires
# 22   91             Malvinas Argentinas         ARG         Buenos Aires
# 23   92                   Vicente López         ARG         Buenos Aires
# 24   93                     Berazategui         ARG         Buenos Aires
# 25   94                      Corrientes         ARG           Corrientes
# 26   95                      San Miguel         ARG         Buenos Aires
# 27   96                    Bahía Blanca         ARG         Buenos Aires
# 28   97              Esteban Echeverría         ARG         Buenos Aires
# 29   98                     Resistencia         ARG                Chaco
# 30   99                     José C. Paz         ARG         Buenos Aires
# 31  100                          Paraná         ARG           Entre Rios
# 32  101                      Godoy Cruz         ARG              Mendoza
# 33  102                         Posadas         ARG             Misiones
# 34  103                      Guaymallén         ARG              Mendoza
# 35  104             Santiago del Estero         ARG  Santiago del Estero
# 36  105           San Salvador de Jujuy         ARG                Jujuy
# 37  106                      Hurlingham         ARG         Buenos Aires
# 38  107                         Neuquén         ARG              Neuquén
# 39  108                       Ituzaingó         ARG         Buenos Aires
# 40  109                    San Fernando         ARG         Buenos Aires
# 41  110                         Formosa         ARG              Formosa
# 42  111                       Las Heras         ARG              Mendoza
# 43  112                        La Rioja         ARG             La Rioja
# 44  113  San Fernando del Valle de Cata         ARG            Catamarca
# 45  114                      Río Cuarto         ARG              Córdoba
# 46  115              Comodoro Rivadavia         ARG               Chubut
# 47  116                         Mendoza         ARG              Mendoza
# 48  117      San Nicolás de los Arroyos         ARG         Buenos Aires
# 49  118                        San Juan         ARG             San Juan
# 50  119                         Escobar         ARG         Buenos Aires
# 51  120                       Concordia         ARG           Entre Rios
# 52  121                           Pilar         ARG         Buenos Aires
# 53  122                        San Luis         ARG             San Luis
# 54  123                          Ezeiza         ARG         Buenos Aires
# 55  124                      San Rafael         ARG              Mendoza
# 56  125                          Tandil         ARG         Buenos Aires
#
#     Population
# 0      2982146
# 1      1266461
# 2      1157507
# 3       907718
# 4       622013
# 5       559249
# 6       538918
# 7       521936
# 8       512880
# 9       470809
# 10      469735
# 11      463846
# 12      422542
# 13      367550
# 14      356993
# 15      353063
# 16      353046
# 17      352311
# 18      349246
# 19      315432
# 20      306341
# 21      296226
# 22      290335
# 23      288341
# 24      276916
# 25      258103
# 26      248700
# 27      239810
# 28      235760
# 29      229212
# 30      221754
# 31      207041
# 32      206998
# 33      201273
# 34      200595
# 35      189947
# 36      178748
# 37      170028
# 38      167296
# 39      158197
# 40      153036
# 41      147636
# 42      145823
# 43      138117
# 44      134935
# 45      134355
# 46      124104
# 47      123027
# 48      119302
# 49      119152
# 50      116675
# 51      116485
# 52      113428
# 53      110136
# 54       99578
# 55       94651
# 56       91101
