# %% [markdown]
# # Creating data set 'Best in Fitness and Nutrition Service company'

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %% [markdown]
# # if response code is 403
# ### headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
# ###### -requests.get('url',headers=headers).text

# %%
headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5)AppleWebKit/605.1.15 (KHTML, like Gecko)Version/12.1.1 Safari/605.1.15'}
webpage = requests.get('https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2', headers= headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')
# print(soup)     
print(soup.prettify()) #make readeable to html page
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="Trustpilot" name="application-name"/>
#   <meta content="#1c1c1c" name="theme-color"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link color="#00b67a" href="https://cdn.trustpilot.net/brand-assets/1.9.0/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="Trustpilot" name="apple-mobile-web-app-title"/>
#   <meta content="#1c1c1c" name="msapplication-TileColor"/>
#   <script>
#    /* 'Disable' Segments Querystring API */
#         (function() {
#           var os = location.search;
#           var ns = os.length ? '?'+os.substring(1).split('&').filter(function(param){return !/^ajs_(aid|event|uid)=/i.test(param);}).join('&') : '';
#           if (typeof window.history === 'object' && os !== ns) {
#             window.history.replaceState({}, '', location.pathname + ns)
#           }
#         })();
#         /* Segment snippet */
#         !function(){var analytics=window.analytics=window.analytics||[];if(!analytics.initialize)if(analytics.invoked)window.console&&console.error&&console.error("Segment snippet included twice.");else{analytics.invoked=!0;analytics.methods=["trackSubmit","trackClick","trackLink","trackForm","pageview","identify","reset","group","track","ready","alias","debug","page","once","off","on","addSourceMiddleware","addIntegrationMiddleware","setAnonymousId","addDestinationMiddleware"];analytics.factory=function(e){return function(){var t=Array.prototype.slice.call(arguments);t.unshift(e);analytics.push(t);return analytics}};for(var e=0;e<analytics.methods.length;e++){var key=analytics.methods[e];analytics[key]=analytics.factory(key)}analytics.load=function(key,e){var t=document.createElement("script");t.type="text/javascript";t.async=!0;t.src="https://cdn.segment.com/analytics.js/v1/" + key + "/analytics.min.js";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n);analytics._loadOptions=e};
#         analytics._writeKey="8tb69qtawc";
#         analytics.SNIPPET_VERSION="4.15.2";
#         }}();
#   </script>
#   <script>
#    (function(h){
#               h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#               h._hjSettings={hjid:391767,hjsv:6};
#             })(window);
#   </script>
#   <script class="optanon-category-C0002" src="https://static.hotjar.com/c/hotjar-391767.js?sv=6" type="text/plain">
#   </script>
#   <link crossorigin="" href="https://categoriespages-cdn.trustpilot.net" rel="preconnect"/>
#   <link crossorigin="" href="https://cdn.trustpilot.net/" rel="preconnect"/>
#   <link crossorigin="" href="https://api.amplitude.com/" rel="preconnect"/>
#   <link crossorigin="" href="https://user-images.trustpilot.com/" rel="preconnect"/>
#   <link href="https://cdn.segment.com/analytics.js/v1/8tb69qtawc/analytics.min.js" rel="prefetch"/>
#   <link href="https://static.hotjar.com/c/hotjar-391767.js?sv=6" rel="prefetch"/>
#   <link crossorigin="" href="https://cdn.cookielaw.org" rel="preconnect"/>
#   <link crossorigin="" href="https://geolocation.onetrust.com" rel="preconnect"/>
#   <script charset="UTF-8" data-domain-script="84cb5c09-05e4-488b-b71c-2fe171dca5e5" data-language="en-US" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="application/javascript">
#   </script>
#   <script>
#    function OptanonWrapper() {
#             var event = new CustomEvent("OptanonWrapper");
#             document.dispatchEvent(event);
#           }
#   </script>
#   <script nomodule="">
#    if (window.location.pathname !== '/error/upgradebrowser') {
#           window.location = '/error/upgradebrowser?status=browser';
#         }
#   </script>
#   <meta content="app-id=1608392803, app-argument=https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2" name="apple-itunes-app"/>
#   <title>
#    Best companies in Fitness and Nutrition Service on Trustpilot | 2 of 27
#   </title>
#   <meta content="Find and compare the best companies in Fitness and Nutrition Service on Trustpilot, and add your own experience" name="description"/>
#   <link href="https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2" rel="canonical"/>
#   <link href="https://www.trustpilot.com/categories/fitness_and_nutrition_service" rel="prev"/>
#   <link href="https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=3" rel="next"/>
#   <meta content="max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <script data-category-json-ld="true" type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"Organization","@id":"https://www.trustpilot.com/#/schema/Organization/1","name":"Trustpilot","legalName":"Trustpilot A/S","url":"https://www.trustpilot.com","description":"Read reviews. Write reviews. Find companies.","sameAs":["https://en.wikipedia.org/wiki/Trustpilot","https://www.facebook.com/Trustpilot/","https://www.instagram.com/trustpilot/","https://www.linkedin.com/company/trustpilot","https://twitter.com/Trustpilot","https://www.youtube.com/c/trustpilotreviews"],"logo":{"@id":"https://www.trustpilot.com/#/schema/ImageObject/Logo/1"},"email":"support@trustpilot.com","address":{"@type":"PostalAddress","@id":"https://www.trustpilot.com/#/schema/PostalAddress/DK","streetAddress":"Pilestræde 58, 5th floor","addressLocality":"Copenhagen","addressCountry":"DK","postalCode":"1112 København"}},{"@type":"ImageObject","@id":"https://www.trustpilot.com/#/schema/ImageObject/Logo/1","url":"https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png","contentUrl":"https://cdn.trustpilot.net/brand-assets/1.5.0/favicons/android-chrome-512x512.png","width":{"@type":"QuantitativeValue","value":512,"unitCode":"E37","unitText":"pixel"},"height":{"@type":"QuantitativeValue","value":512,"unitCode":"E37","unitText":"pixel"},"caption":"Trustpilot Logo","name":"Trustpilot"},{"@type":"WebSite","@id":"https://www.trustpilot.com/#/schema/WebSite/1","url":"https://www.trustpilot.com/","name":"Trustpilot (en-US)","description":"We're all about consumer reviews. Get the real inside story from shoppers like you. Read, write and share reviews on Trustpilot today.","publisher":{"@id":"https://www.trustpilot.com/#/schema/Organization/1"},"copyrightHolder":{"@id":"https://www.trustpilot.com/#/schema/Organization/1"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.trustpilot.com/search?query={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"CollectionPage","@id":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2","url":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2","name":"Best in Fitness and Nutrition Service","description":"Find and compare the best companies in Fitness and Nutrition Service on Trustpilot, and add your own experience","isPartOf":{"@id":"https://www.trustpilot.com/#/schema/WebSite/1"},"inLanguage":"en-US","breadcrumb":{"@id":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2/#/schema/BreadcrumbList/1"}},{"@type":"BreadcrumbList","@id":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2/#/schema/BreadcrumbList/1","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://www.trustpilot.com/","sameAs":"https://www.trustpilot.com/"},{"@type":"ListItem","position":2,"name":"Beauty & Well-being","item":"https://www.trustpilot.com/categories/beauty_wellbeing","sameAs":"https://www.trustpilot.com/categories/beauty_wellbeing"},{"@type":"ListItem","position":3,"name":"Personal Care","item":"https://www.trustpilot.com/categories/personal_care","sameAs":"https://www.trustpilot.com/categories/personal_care"},{"@type":"ListItem","position":4,"name":"Best in Fitness and Nutrition Service","item":{"@id":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2"}}]}]}
#   </script>
#   <meta content="34" name="next-head-count"/>
#   <meta content="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" property="csp-nonce"/>
#   <link as="style" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/574c949eafd607a8.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="preload"/>
#   <link data-n-g="" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/574c949eafd607a8.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="stylesheet"/>
#   <link as="style" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/00e51686bd3643fd.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="preload"/>
#   <link data-n-p="" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/00e51686bd3643fd.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="stylesheet"/>
#   <link as="style" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/5057830365c8720c.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="preload"/>
#   <link data-n-p="" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/5057830365c8720c.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="stylesheet"/>
#   <link as="style" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/31cac2eb49b880e3.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="preload"/>
#   <link data-n-p="" href="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/css/31cac2eb49b880e3.css" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" rel="stylesheet"/>
#   <noscript data-n-css="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=">
#   </noscript>
#   <script defer="" nomodule="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/webpack-82f5319018ed1a8e.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/framework-8b7974553b1447ee.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/main-b9d1015b1b883fe9.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/pages/_app-cb7574614526c8ba.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/571-2803a5607b6fd6fa.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/399-9a88914f3f797439.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/21-30e4dd4d6007dfc2.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/592-783208c53dc72b73.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/chunks/pages/categories/%5BcategoryId%5D-d7b0025ebb8cb6d5.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/categoriespages-consumersite-3487/_buildManifest.js">
#   </script>
#   <script defer="" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" src="https://categoriespages-cdn.trustpilot.net/categoriespages-consumersite/_next/static/categoriespages-consumersite-3487/_ssgManifest.js">
#   </script>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div class="theme-provider_themeProvider__MkYcR theme-provider_theme-default__IISCt" data-constellation-theme="default">
#     <div class="layout_wrapper__s2pss">
#      <div class="section-theme-provider_theme-black__InpVD" data-constellation-section-theme="black">
#       <header class="styles_header__dNzk0">
#        <div class="styles_headerInner__EmLcd" data-navigation="true">
#         <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_logo__PkLy8" data-company-logo-link="true" href="/" name="company-logo" target="_self">
#          <img alt="Trustpilot reviews" src="https://cdn.trustpilot.net/brand-assets/1.1.0/logo-white.svg" width="140"/>
#         </a>
#         <div class="styles_midSection__jsFhX">
#          <div class="search-desktop_searchWithAutoCompleteWrapper___WXpW section-theme-provider_theme-default__zZfHS" data-constellation-section-theme="default">
#           <form autocomplete="off" class="search-desktop_searchWithAutoComplete__CLWER">
#            <div class="search-desktop_searchForm____um1">
#             <div class="search-desktop_iconWrapperDesktop__wxRLm">
#              <svg class="icon_icon__ECGRl icon_appearance-default___4uy_" height="20px" viewbox="0 0 16 16" width="20px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M3 6.75a3.75 3.75 0 1 1 7.5 0 3.75 3.75 0 0 1-7.5 0ZM6.75 2a4.75 4.75 0 1 0 2.987 8.444l3.91 3.91.707-.708-3.91-3.91A4.75 4.75 0 0 0 6.75 2Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </div>
#             <input class="search-desktop_searchInputField__CHV3l" data-header-search-field="true" name="query" placeholder="Search for a company or category…" type="search" value=""/>
#            </div>
#           </form>
#          </div>
#         </div>
#         <button aria-label="Search" class="search-button_wrapper__22ENQ styles_button__P_ISf styles_mobile__T6WU6" data-header-search-button="true" type="button">
#          <svg class="icon_icon__ECGRl icon_appearance-action__9bJa5" fill="inherit" height="24px" viewbox="0 0 16 16" width="24px" xmlns="http://www.w3.org/2000/svg">
#           <path clip-rule="evenodd" d="M3 6.75a3.75 3.75 0 1 1 7.5 0 3.75 3.75 0 0 1-7.5 0ZM6.75 2a4.75 4.75 0 1 0 2.987 8.444l3.91 3.91.707-.708-3.91-3.91A4.75 4.75 0 0 0 6.75 2Z" fill-rule="evenodd">
#           </path>
#          </svg>
#         </button>
#         <button aria-label="Open menu" class="styles_menu__oBlC_ styles_button__P_ISf styles_mobile__T6WU6" data-header-menu="true">
#          <span class="styles_line__kJGW2 styles_top__y0Pt7">
#          </span>
#          <span class="styles_line__kJGW2 styles_middle__85Xgu">
#          </span>
#          <span class="styles_line__kJGW2 styles_bottom__LRKKA">
#          </span>
#         </button>
#         <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" href="/categories" target="_self">
#          <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#           Categories
#          </span>
#         </a>
#         <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" href="/blog" target="_self">
#          <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#           Blog
#          </span>
#         </a>
#         <a class="link_internal__7XN06 link_wrapper__5ZJEx styles_headerLink__L1R6L styles_desktop__qrPiX" data-navigation-login-desktop-link="true" href="/users/connect?redirect=" name="navigation-login-desktop" rel="nofollow" target="_self">
#          <span class="typography_body-m__xgxZ_ typography_appearance-default__AAY17 styles_headerLinkInner__W_yvf">
#           Log in
#          </span>
#         </a>
#         <a class="link_internal__7XN06 button_button__T34Lr button_m__lq0nA button_appearance-primary__wuIev link_button___108l styles_desktop__qrPiX" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=for_companies&amp;utm_campaign=consumer_cta" target="_self">
#          <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7">
#           For businesses
#          </span>
#         </a>
#        </div>
#        <div class="styles_wrapper__sY8AQ styles_sidePanel__MHj7K styles_mobile__T6WU6">
#         <div aria-label="Close menu" class="styles_background__yoleK" role="button">
#         </div>
#         <div class="styles_content__hG1k0">
#          <div class="styles_wrapper__ti9Ds">
#           <div class="styles_inner__LD4m2" data-navigation="true">
#            <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-action__9NNRY link_link__IZzHN link_underlined__OXYVM" data-navigation-login-mobile-typography="true" href="/users/connect?redirect=" rel="nofollow" target="_self">
#             Log in
#             <span class="styles_arrow__2_Iab">
#              <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 12 11" width="16px" xmlns="http://www.w3.org/2000/svg">
#               <path d="M10.192 5.033 6.277 1.16 6.944.5 12 5.5l-5.056 5-.667-.66 3.915-3.873H0v-.934h10.192Z">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki" href="/blog" target="_self">
#             Blog
#            </a>
#            <a class="link_internal__7XN06 typography_heading-s__f7029 typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki" href="/categories" target="_self">
#             Categories
#            </a>
#            <a class="link_internal__7XN06 button_button__T34Lr button_l__mm_bi button_appearance-primary__wuIev link_button___108l" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=for_companies&amp;utm_campaign=consumer_cta" target="_self">
#             <span class="typography_heading-xs__jSwUz typography_appearance-inherit__D7XqR typography_disableResponsiveSizing__OuNP7">
#              For businesses
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </header>
#      </div>
#      <main class="layout_content__o0ojo" role="main">
#       <div class="styles_wrapper__2vU7q">
#        <div class="styles_headingWrapper__J5szX">
#         <div class="styles_container__CwUuL styles_widthControlled__lh3qu">
#          <nav aria-label="Breadcrumb" class="breadcrumb_breadcrumbs__SkZLS styles_breadcrumbs__BWcRG">
#           <ol class="breadcrumb_breadcrumbList__Wa1xu">
#            <li class="breadcrumb_breadcrumb__lJO__ breadcrumb_ellipsis__9WmPs">
#             <button aria-label="Show all breadcrumbs" class="button_button__T34Lr button_l__mm_bi button_appearance-link__ANr2s breadcrumb_breadcrumbLink__p1PMo" data-breadcrumb-ellipsis-button="true" name="Breadcrumb ellipsis" title="Show all breadcrumbs" type="button">
#              <span class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 typography_disableResponsiveSizing__OuNP7 button_buttonText__xmelJ">
#               <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                <path d="M2 10a2 2 0 1 0 0-4 2 2 0 0 0 0 4ZM14 10a2 2 0 1 0 0-4 2 2 0 0 0 0 4ZM10 8a2 2 0 1 1-4 0 2 2 0 0 1 4 0Z">
#                </path>
#               </svg>
#              </span>
#             </button>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__ breadcrumb_hideWithEllipsis__Wef3t">
#             <a class="link_internal__7XN06 typography_body-s__aY15Q typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" href="/categories/beauty_wellbeing" target="_self">
#              Beauty &amp; Well-being
#             </a>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__">
#             <a class="link_internal__7XN06 typography_body-s__aY15Q typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" href="/categories/personal_care" target="_self">
#              Personal Care
#             </a>
#             <span class="breadcrumb_arrowIcon__elXuT">
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="10px" viewbox="0 0 16 16" width="10px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M10.51 7.776 3.953 2.158l.65-.759 7.444 6.377-7.443 6.382-.651-.759 6.557-5.623Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </li>
#            <li class="breadcrumb_breadcrumb__lJO__">
#             <a aria-current="page" aria-disabled="true" class="link_internal__7XN06 link_disabled__mIxH1 typography_body-s__aY15Q typography_appearance-subtle__8_H2l link_link__IZzHN link_notUnderlined__szqki breadcrumb_breadcrumbLink__p1PMo" tabindex="-1" target="_self">
#              Fitness and Nutrition Service
#             </a>
#            </li>
#           </ol>
#          </nav>
#          <div class="styles_headings__ToYdZ">
#           <div class="styles_mainHeading__panBC">
#            <h1 class="typography_display-m__bfVwY typography_appearance-default__AAY17">
#             Best in Fitness and Nutrition Service
#             <span class="styles_tooltipMobile__6C7SP">
#              <span>
#               <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="12px" viewbox="0 0 16 16" width="12px" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">
#                </path>
#                <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#             </span>
#            </h1>
#           </div>
#           <div class="styles_subHeading__wsowK">
#            <p class="typography_body-l__KUYFJ typography_appearance-subtle__8_H2l">
#             Compare the best companies in this category
#            </p>
#            <div class="styles_tooltipDesktop__d7oDa">
#             <span>
#              <svg class="icon_icon__ECGRl icon_appearance-subtle__9l3Sf" fill="inherit" height="12px" viewbox="0 0 16 16" width="12px" xmlns="http://www.w3.org/2000/svg">
#               <path clip-rule="evenodd" d="M8 1a7 7 0 1 0 0 14A7 7 0 0 0 8 1ZM0 8a8 8 0 1 1 16 0A8 8 0 0 1 0 8Z" fill-rule="evenodd">
#               </path>
#               <path clip-rule="evenodd" d="M7.5 7h-.75V6H8.5v5.502h.75v1h-2.5v-1h.75V7ZM6.75 4a1 1 0 1 1 2 0 1 1 0 0 1-2 0Z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="styles_body__WGdpu">
#         <aside class="styles_desktop__A2Tz2 styles_aside__W8bqt">
#          <div class="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv styles_wrapper__ylyic styles_asideItem__L0Qpz">
#           <fieldset class="styles_wrapper__c1ZnQ styles_fieldset__uRF8r">
#            <legend class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_legend__cqrWG">
#             Rating
#            </legend>
#            <div class="button-toggle_container__aX52V" data-trustscore-filter-button-toggle="true">
#             <div class="styles_itemWrapper__VHiJR">
#              <label class="button-toggle_item__S4xKn button-toggle_medium__ZYSqq button-toggle_checked__i38b8 button-toggle_button-toggle-icon__F7exh" data-trustscore-filter-button-toggle-label="true">
#               <input checked="" class="button-toggle_input___B1T_" data-trustscore-filter-button-toggle-input="true" name="trustscore-filter" type="radio"/>
#               <span class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17 button-toggle_label__oVsKu">
#                <span class="styles_buttonInner__P0Z6X">
#                 <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">
#                  Any
#                 </span>
#                </span>
#               </span>
#              </label>
#              <label class="button-toggle_item__S4xKn button-toggle_medium__ZYSqq button-toggle_button-toggle-icon__F7exh" data-trustscore-filter-button-toggle-label="true">
#               <input class="button-toggle_input___B1T_" data-trustscore-filter-button-toggle-input="true" name="trustscore-filter" type="radio"/>
#               <span class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17 button-toggle_label__oVsKu">
#                <span class="styles_buttonInner__P0Z6X">
#                 <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                  <path clip-rule="evenodd" d="M9.88 6.225H16l-4.929 3.504-3.047 2.149-4.953 3.504L4.952 9.73 0 6.225h6.119L8 .572l1.881 5.653Zm1.596 4.812L8 11.9l4.929 3.527-1.453-4.392Z" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">
#                  3.0
#                  <!-- -->
#                  +
#                 </span>
#                </span>
#               </span>
#              </label>
#              <label class="button-toggle_item__S4xKn button-toggle_medium__ZYSqq button-toggle_button-toggle-icon__F7exh" data-trustscore-filter-button-toggle-label="true">
#               <input class="button-toggle_input___B1T_" data-trustscore-filter-button-toggle-input="true" name="trustscore-filter" type="radio"/>
#               <span class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17 button-toggle_label__oVsKu">
#                <span class="styles_buttonInner__P0Z6X">
#                 <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                  <path clip-rule="evenodd" d="M9.88 6.225H16l-4.929 3.504-3.047 2.149-4.953 3.504L4.952 9.73 0 6.225h6.119L8 .572l1.881 5.653Zm1.596 4.812L8 11.9l4.929 3.527-1.453-4.392Z" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">
#                  4.0
#                  <!-- -->
#                  +
#                 </span>
#                </span>
#               </span>
#              </label>
#              <label class="button-toggle_item__S4xKn button-toggle_medium__ZYSqq button-toggle_button-toggle-icon__F7exh" data-trustscore-filter-button-toggle-label="true">
#               <input class="button-toggle_input___B1T_" data-trustscore-filter-button-toggle-input="true" name="trustscore-filter" type="radio"/>
#               <span class="typography_heading-xxs__QKBS8 typography_appearance-default__AAY17 button-toggle_label__oVsKu">
#                <span class="styles_buttonInner__P0Z6X">
#                 <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="16px" viewbox="0 0 16 16" width="16px" xmlns="http://www.w3.org/2000/svg">
#                  <path clip-rule="evenodd" d="M9.88 6.225H16l-4.929 3.504-3.047 2.149-4.953 3.504L4.952 9.73 0 6.225h6.119L8 .572l1.881 5.653Zm1.596 4.812L8 11.9l4.929 3.527-1.453-4.392Z" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="typography_heading-xxs__QKBS8 typography_appearance-inherit__D7XqR">
#                  4.5
#                  <!-- -->
#                  +
#                 </span>
#                </span>
#               </span>
#              </label>
#             </div>
#            </div>
#           </fieldset>
#           <fieldset class="styles_wrapper__c1ZnQ styles_fieldset__uRF8r">
#            <legend class="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_legend__cqrWG">
#             Location
#            </legend>
#            <div class="styles_wrapper__OjsW0">
#             <select aria-label="Country" class="styles_select__V5fiP styles_select--l___xC_g" data-country-selector-filter-select="true">
#              <option value="AF">
#               Afghanistan
#              </option>
#              <option value="AX">
#               Åland Islands
#              </option>
#              <option value="AL">
#               Albania
#              </option>
#              <option value="DZ">
#               Algeria
#              </option>
#              <option value="AS">
#               American Samoa
#              </option>
#              <option value="AD">
#               Andorra
#              </option>
#              <option value="AO">
#               Angola
#              </option>
#              <option value="AI">
#               Anguilla
#              </option>
#              <option value="AQ">
#               Antarctica
#              </option>
#              <option value="AG">
#               Antigua &amp; Barbuda
#              </option>
#              <option value="AR">
#               Argentina
#              </option>
#              <option value="AM">
#               Armenia
#              </option>
#              <option value="AW">
#               Aruba
#              </option>
#              <option value="AU">
#               Australia
#              </option>
#              <option value="AT">
#               Austria
#              </option>
#              <option value="AZ">
#               Azerbaijan
#              </option>
#              <option value="BS">
#               Bahamas
#              </option>
#              <option value="BH">
#               Bahrain
#              </option>
#              <option value="BD">
#               Bangladesh
#              </option>
#              <option value="BB">
#               Barbados
#              </option>
#              <option value="BY">
#               Belarus
#              </option>
#              <option value="BE">
#               Belgium
#              </option>
#              <option value="BZ">
#               Belize
#              </option>
#              <option value="BJ">
#               Benin
#              </option>
#              <option value="BM">
#               Bermuda
#              </option>
#              <option value="BT">
#               Bhutan
#              </option>
#              <option value="BO">
#               Bolivia
#              </option>
#              <option value="BA">
#               Bosnia And Herzegovina
#              </option>
#              <option value="BW">
#               Botswana
#              </option>
#              <option value="BV">
#               Bouvet Island
#              </option>
#              <option value="BR">
#               Brazil
#              </option>
#              <option value="IO">
#               British Indian Ocean Territory
#              </option>
#              <option value="VG">
#               British Virgin Islands
#              </option>
#              <option value="BN">
#               Brunei
#              </option>
#              <option value="BG">
#               Bulgaria
#              </option>
#              <option value="BF">
#               Burkina Faso
#              </option>
#              <option value="BI">
#               Burundi
#              </option>
#              <option value="KH">
#               Cambodia
#              </option>
#              <option value="CM">
#               Cameroon
#              </option>
#              <option value="CA">
#               Canada
#              </option>
#              <option value="CV">
#               Cape Verde
#              </option>
#              <option value="BQ">
#               Caribbean Netherlands
#              </option>
#              <option value="KY">
#               Cayman Islands
#              </option>
#              <option value="CF">
#               Central African Republic
#              </option>
#              <option value="TD">
#               Chad
#              </option>
#              <option value="CL">
#               Chile
#              </option>
#              <option value="CN">
#               China
#              </option>
#              <option value="CX">
#               Christmas Island
#              </option>
#              <option value="CC">
#               Cocos (Keeling) Islands
#              </option>
#              <option value="CO">
#               Colombia
#              </option>
#              <option value="KM">
#               Comoros
#              </option>
#              <option value="CG">
#               Congo - Brazzaville
#              </option>
#              <option value="CK">
#               Cook Islands
#              </option>
#              <option value="CR">
#               Costa Rica
#              </option>
#              <option value="CI">
#               Côte d’Ivoire
#              </option>
#              <option value="HR">
#               Croatia
#              </option>
#              <option value="CU">
#               Cuba
#              </option>
#              <option value="CW">
#               Curaçao
#              </option>
#              <option value="CY">
#               Cyprus
#              </option>
#              <option value="CZ">
#               Czech Republic
#              </option>
#              <option value="DK">
#               Denmark
#              </option>
#              <option value="DJ">
#               Djibouti
#              </option>
#              <option value="DM">
#               Dominica
#              </option>
#              <option value="DO">
#               Dominican Republic
#              </option>
#              <option value="EC">
#               Ecuador
#              </option>
#              <option value="EG">
#               Egypt
#              </option>
#              <option value="SV">
#               El Salvador
#              </option>
#              <option value="GQ">
#               Equatorial Guinea
#              </option>
#              <option value="ER">
#               Eritrea
#              </option>
#              <option value="EE">
#               Estonia
#              </option>
#              <option value="ET">
#               Ethiopia
#              </option>
#              <option value="FK">
#               Falkland Islands
#              </option>
#              <option value="FO">
#               Faroe Islands
#              </option>
#              <option value="FJ">
#               Fiji
#              </option>
#              <option value="FI">
#               Finland
#              </option>
#              <option value="FR">
#               France
#              </option>
#              <option value="GF">
#               French Guiana
#              </option>
#              <option value="PF">
#               French Polynesia
#              </option>
#              <option value="TF">
#               French Southern Territories
#              </option>
#              <option value="GA">
#               Gabon
#              </option>
#              <option value="GM">
#               Gambia
#              </option>
#              <option value="GE">
#               Georgia
#              </option>
#              <option value="DE">
#               Germany
#              </option>
#              <option value="GH">
#               Ghana
#              </option>
#              <option value="GI">
#               Gibraltar
#              </option>
#              <option value="GR">
#               Greece
#              </option>
#              <option value="GL">
#               Greenland
#              </option>
#              <option value="GD">
#               Grenada
#              </option>
#              <option value="GP">
#               Guadeloupe
#              </option>
#              <option value="GU">
#               Guam
#              </option>
#              <option value="GT">
#               Guatemala
#              </option>
#              <option value="GG">
#               Guernsey
#              </option>
#              <option value="GN">
#               Guinea
#              </option>
#              <option value="GW">
#               Guinea-Bissau
#              </option>
#              <option value="GY">
#               Guyana
#              </option>
#              <option value="HT">
#               Haiti
#              </option>
#              <option value="HM">
#               Heard &amp; McDonald Islands
#              </option>
#              <option value="HN">
#               Honduras
#              </option>
#              <option value="HK">
#               Hong Kong
#              </option>
#              <option value="HU">
#               Hungary
#              </option>
#              <option value="IS">
#               Iceland
#              </option>
#              <option value="IN">
#               India
#              </option>
#              <option value="ID">
#               Indonesia
#              </option>
#              <option value="IR">
#               Iran
#              </option>
#              <option value="IQ">
#               Iraq
#              </option>
#              <option value="IE">
#               Ireland
#              </option>
#              <option value="IM">
#               Isle of Man
#              </option>
#              <option value="IL">
#               Israel
#              </option>
#              <option value="IT">
#               Italy
#              </option>
#              <option value="JM">
#               Jamaica
#              </option>
#              <option value="JP">
#               Japan
#              </option>
#              <option value="JE">
#               Jersey
#              </option>
#              <option value="JO">
#               Jordan
#              </option>
#              <option value="KZ">
#               Kazakhstan
#              </option>
#              <option value="KE">
#               Kenya
#              </option>
#              <option value="KI">
#               Kiribati
#              </option>
#              <option value="XK">
#               Kosovo
#              </option>
#              <option value="KW">
#               Kuwait
#              </option>
#              <option value="KG">
#               Kyrgyzstan
#              </option>
#              <option value="LA">
#               Lao P.D.R.
#              </option>
#              <option value="LV">
#               Latvia
#              </option>
#              <option value="LB">
#               Lebanon
#              </option>
#              <option value="LS">
#               Lesotho
#              </option>
#              <option value="LR">
#               Liberia
#              </option>
#              <option value="LY">
#               Libya
#              </option>
#              <option value="LI">
#               Liechtenstein
#              </option>
#              <option value="LT">
#               Lithuania
#              </option>
#              <option value="LU">
#               Luxembourg
#              </option>
#              <option value="MO">
#               Macao S.A.R.
#              </option>
#              <option value="MK">
#               Macedonia (FYROM)
#              </option>
#              <option value="MG">
#               Madagascar
#              </option>
#              <option value="MW">
#               Malawi
#              </option>
#              <option value="MY">
#               Malaysia
#              </option>
#              <option value="MV">
#               Maldives
#              </option>
#              <option value="ML">
#               Mali
#              </option>
#              <option value="MT">
#               Malta
#              </option>
#              <option value="MH">
#               Marshall Islands
#              </option>
#              <option value="MQ">
#               Martinique
#              </option>
#              <option value="MR">
#               Mauritania
#              </option>
#              <option value="MU">
#               Mauritius
#              </option>
#              <option value="YT">
#               Mayotte
#              </option>
#              <option value="MX">
#               Mexico
#              </option>
#              <option value="FM">
#               Micronesia
#              </option>
#              <option value="MD">
#               Moldova
#              </option>
#              <option value="MN">
#               Mongolia
#              </option>
#              <option value="ME">
#               Montenegro
#              </option>
#              <option value="MS">
#               Montserrat
#              </option>
#              <option value="MA">
#               Morocco
#              </option>
#              <option value="MZ">
#               Mozambique
#              </option>
#              <option value="MM">
#               Myanmar
#              </option>
#              <option value="NA">
#               Namibia
#              </option>
#              <option value="NR">
#               Nauru
#              </option>
#              <option value="NP">
#               Nepal
#              </option>
#              <option value="NL">
#               Netherlands
#              </option>
#              <option value="NC">
#               New Caledonia
#              </option>
#              <option value="NZ">
#               New Zealand
#              </option>
#              <option value="NI">
#               Nicaragua
#              </option>
#              <option value="NE">
#               Niger
#              </option>
#              <option value="NG">
#               Nigeria
#              </option>
#              <option value="NU">
#               Niue
#              </option>
#              <option value="NF">
#               Norfolk Island
#              </option>
#              <option value="KP">
#               North Korea
#              </option>
#              <option value="MP">
#               Northern Mariana Islands
#              </option>
#              <option value="NO">
#               Norway
#              </option>
#              <option value="OM">
#               Oman
#              </option>
#              <option value="PK">
#               Pakistan
#              </option>
#              <option value="PW">
#               Palau
#              </option>
#              <option value="PS">
#               Palestine
#              </option>
#              <option value="PA">
#               Panama
#              </option>
#              <option value="PG">
#               Papua New Guinea
#              </option>
#              <option value="PY">
#               Paraguay
#              </option>
#              <option value="PE">
#               Peru
#              </option>
#              <option value="PH">
#               Philippines
#              </option>
#              <option value="PN">
#               Pitcairn Islands
#              </option>
#              <option value="PL">
#               Poland
#              </option>
#              <option value="PT">
#               Portugal
#              </option>
#              <option value="MC">
#               Principality of Monaco
#              </option>
#              <option value="PR">
#               Puerto Rico
#              </option>
#              <option value="QA">
#               Qatar
#              </option>
#              <option value="CD">
#               Republic of Congo
#              </option>
#              <option value="RE">
#               Réunion
#              </option>
#              <option value="RO">
#               Romania
#              </option>
#              <option value="RU">
#               Russia
#              </option>
#              <option value="RW">
#               Rwanda
#              </option>
#              <option value="WS">
#               Samoa
#              </option>
#              <option value="SM">
#               San Marino
#              </option>
#              <option value="ST">
#               São Tomé &amp; Príncipe
#              </option>
#              <option value="SA">
#               Saudi Arabia
#              </option>
#              <option value="SN">
#               Senegal
#              </option>
#              <option value="RS">
#               Serbia
#              </option>
#              <option value="SC">
#               Seychelles
#              </option>
#              <option value="SL">
#               Sierra Leone
#              </option>
#              <option value="SG">
#               Singapore
#              </option>
#              <option value="SX">
#               Sint Maarten
#              </option>
#              <option value="SK">
#               Slovakia
#              </option>
#              <option value="SI">
#               Slovenia
#              </option>
#              <option value="SB">
#               Solomon Islands
#              </option>
#              <option value="SO">
#               Somalia
#              </option>
#              <option value="ZA">
#               South Africa
#              </option>
#              <option value="GS">
#               South Georgia &amp; South Sandwich Islands
#              </option>
#              <option value="KR">
#               South Korea
#              </option>
#              <option value="SS">
#               South Sudan
#              </option>
#              <option value="ES">
#               Spain
#              </option>
#              <option value="LK">
#               Sri Lanka
#              </option>
#              <option value="BL">
#               St. Barthélemy
#              </option>
#              <option value="SH">
#               St. Helena
#              </option>
#              <option value="KN">
#               St. Kitts &amp; Nevis
#              </option>
#              <option value="LC">
#               St. Lucia
#              </option>
#              <option value="MF">
#               St. Martin
#              </option>
#              <option value="PM">
#               St. Pierre &amp; Miquelon
#              </option>
#              <option value="VC">
#               St. Vincent &amp; Grenadines
#              </option>
#              <option value="SD">
#               Sudan
#              </option>
#              <option value="SR">
#               Suriname
#              </option>
#              <option value="SJ">
#               Svalbard &amp; Jan Mayen
#              </option>
#              <option value="SZ">
#               Swaziland
#              </option>
#              <option value="SE">
#               Sweden
#              </option>
#              <option value="CH">
#               Switzerland
#              </option>
#              <option value="SY">
#               Syria
#              </option>
#              <option value="TW">
#               Taiwan
#              </option>
#              <option value="TJ">
#               Tajikistan
# ...
#             Log in
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://www.trustpilot.com/users/connect?signup=True" target="_self">
#             Sign up
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://chrome.google.com/webstore/detail/trustpilot/meagmjlgkihmljnchdjagbcgfclobkho" rel="noopener" target="_blank">
#             Chrome App
#            </a>
#           </li>
#          </ul>
#         </section>
#         <section class="footer_section__U1AL6">
#          <h3 class="typography_heading-xs__jSwUz typography_appearance-subtle__8_H2l">
#           Businesses
#          </h3>
#          <ul class="footer_links__qMPsg">
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site&amp;utm_campaign=consumer_cta" target="_self">
#             Trustpilot Business
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/features?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site_product_tour&amp;utm_campaign=consumer_cta" target="_self">
#             Products
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/pricing?utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_site_plans&amp;utm_campaign=consumer_cta" target="_self">
#             Plans &amp; Pricing
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://businessapp.b2b.trustpilot.com/?locale=en-us&amp;utm_medium=consumer&amp;utm_source=footer_link_trustpilot_business_app_login&amp;utm_campaign=consumer_cta" rel="nofollow" target="_self">
#             Business Login
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://business.trustpilot.com/reviews" target="_self">
#             Blog for Business
#            </a>
#           </li>
#          </ul>
#         </section>
#         <section class="footer_section__U1AL6">
#          <h3 class="typography_heading-xs__jSwUz typography_appearance-subtle__8_H2l">
#           Follow us on
#          </h3>
#          <ul class="footer_links__qMPsg footer_links--horizontal-phone__Fef4B">
#           <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#            <a aria-label="Facebook" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-facebook-icon-link="true" href="https://www.facebook.com/Trustpilot/" name="Facebook-icon" rel="noopener" target="_blank" title="Facebook">
#             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#              <path d="m11.469 8-.355 2.313H9.25v5.59a8 8 0 1 0-2.5 0v-5.59H4.719V8H6.75V6.237c0-2.005 1.194-3.112 3.022-3.112a12.034 12.034 0 0 1 1.79.156V5.25h-1.008a2.18 2.18 0 0 0-.179.007c-.853.07-1.125.65-1.125 1.242V8h2.219Z">
#              </path>
#             </svg>
#            </a>
#           </li>
#           <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#            <a aria-label="Twitter" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-twitter-icon-link="true" href="https://twitter.com/Trustpilot" name="Twitter-icon" rel="noopener" target="_blank" title="Twitter">
#             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#              <path d="M14.362 5.236c.01.141.01.282.01.425 0 4.337-3.302 9.339-9.34 9.339v-.003A9.294 9.294 0 0 1 0 13.526a6.592 6.592 0 0 0 4.858-1.36 3.287 3.287 0 0 1-3.067-2.28c.492.095 1 .076 1.482-.056A3.283 3.283 0 0 1 .64 6.612v-.041c.457.254.967.395 1.49.41A3.286 3.286 0 0 1 1.114 2.6 9.317 9.317 0 0 0 7.88 6.028a3.284 3.284 0 0 1 5.594-2.994 6.587 6.587 0 0 0 2.085-.797 3.295 3.295 0 0 1-1.443 1.816A6.53 6.53 0 0 0 16 3.536a6.668 6.668 0 0 1-1.638 1.7Z">
#              </path>
#             </svg>
#            </a>
#           </li>
#           <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#            <a aria-label="Instagram" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-instagram-icon-link="true" href="https://www.instagram.com/trustpilot/" name="Instagram-icon" rel="noopener" target="_blank" title="Instagram">
#             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#              <path d="M4.687.056c-.851.04-1.433.176-1.94.376-.527.205-.973.48-1.416.925a3.919 3.919 0 0 0-.92 1.418c-.197.509-.33 1.09-.368 1.942C.005 5.57-.003 5.843 0 8.015c.004 2.173.014 2.445.055 3.298.04.852.176 1.433.376 1.941.205.526.48.972.925 1.415.445.444.891.716 1.419.92.509.197 1.09.331 1.942.368.852.037 1.126.046 3.298.042 2.171-.004 2.445-.014 3.298-.054.854-.04 1.432-.177 1.94-.376.526-.206.972-.48 1.415-.925a3.92 3.92 0 0 0 .92-1.42c.197-.508.331-1.09.368-1.94.037-.855.046-1.127.042-3.3-.004-2.172-.014-2.444-.055-3.297-.04-.853-.176-1.432-.375-1.941a3.928 3.928 0 0 0-.925-1.415 3.905 3.905 0 0 0-1.419-.92c-.509-.197-1.09-.331-1.942-.368-.852-.037-1.126-.046-3.298-.042C5.812.005 5.54.014 4.687.056Zm.093 14.462c-.78-.034-1.203-.164-1.486-.272a2.49 2.49 0 0 1-.92-.597 2.465 2.465 0 0 1-.6-.918c-.11-.283-.242-.706-.279-1.486-.04-.843-.048-1.096-.053-3.232-.004-2.135.004-2.388.04-3.232.034-.779.165-1.203.273-1.485.144-.374.317-.64.597-.921a2.47 2.47 0 0 1 .918-.6c.282-.11.705-.241 1.485-.278.844-.04 1.097-.048 3.232-.053 2.136-.005 2.389.003 3.233.04.78.034 1.204.163 1.485.272.374.144.64.317.921.597.282.28.455.545.6.92.111.28.242.703.279 1.483.04.844.049 1.097.053 3.232.004 2.136-.004 2.39-.04 3.232-.035.78-.164 1.204-.273 1.487a2.48 2.48 0 0 1-.597.92c-.28.282-.545.455-.919.6-.281.11-.705.242-1.484.279-.843.04-1.096.048-3.233.053-2.136.004-2.388-.004-3.232-.041Zm6.522-10.794a.961.961 0 1 0 1.922-.004.961.961 0 0 0-1.922.004Zm-7.41 4.284a4.107 4.107 0 1 0 8.215-.016 4.107 4.107 0 0 0-8.215.016Zm1.441-.003a2.667 2.667 0 1 1 5.334-.01 2.667 2.667 0 0 1-5.334.01Z">
#              </path>
#             </svg>
#            </a>
#           </li>
#           <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#            <a aria-label="LinkedIn" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-linkedin-icon-link="true" href="https://www.linkedin.com/company/trustpilot/" name="LinkedIn-icon" rel="noopener" target="_blank" title="LinkedIn">
#             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#              <path d="M13.637 13.637h-2.405V9.463c0-1.231-.524-1.61-1.199-1.61-.714 0-1.414.536-1.414 1.64v4.144H6.214V5.995h2.313v1.059h.031c.233-.47 1.045-1.273 2.287-1.273 1.342 0 2.792.795 2.792 3.13v4.726ZM3.567 4.93C2.8 4.93 2.18 4.348 2.18 3.55s.62-1.382 1.387-1.382c.766 0 1.386.584 1.386 1.382 0 .798-.62 1.38-1.386 1.38Zm1.202 8.7H2.364V5.989h2.405v7.642ZM14.82 0H1.182C.529 0 0 .53 0 1.182v13.637C0 15.471.53 16 1.182 16h13.637a1.18 1.18 0 0 0 1.182-1.18V1.181C16 .529 15.47 0 14.819 0Z">
#              </path>
#             </svg>
#            </a>
#           </li>
#           <li class="social-media-icon-link_socialMediaIconLink__CQrTV">
#            <a aria-label="Youtube" class="link_internal__7XN06 link_wrapper__5ZJEx social-media-icon-link_link__ABaJ7" data-youtube-icon-link="true" href="https://www.youtube.com/c/trustpilotreviews" name="Youtube-icon" rel="noopener" target="_blank" title="Youtube">
#             <svg class="icon_icon__ECGRl icon_appearance-inherit__EpnEx" fill="inherit" height="18px" viewbox="0 0 16 16" width="18px" xmlns="http://www.w3.org/2000/svg">
#              <path d="M6.4 10.472V5.689l4.157 2.391L6.4 10.472Zm9.266-6.23a2 2 0 0 0-1.415-1.409C13.003 2.5 8 2.5 8 2.5s-5.003 0-6.251.333a2 2 0 0 0-1.415 1.41C0 5.486 0 8.08 0 8.08s0 2.594.334 3.838a2 2 0 0 0 1.415 1.41C2.997 13.66 8 13.66 8 13.66s5.003 0 6.251-.334a2 2 0 0 0 1.415-1.41C16 10.675 16 8.08 16 8.08s0-2.594-.334-3.837Z">
#              </path>
#             </svg>
#            </a>
#           </li>
#          </ul>
#         </section>
#         <div class="footer_legal__b5wpP">
#          <ul class="footer_links__qMPsg footer_linksHorizontalWhenPossible__48psW">
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com" target="_self">
#             Legal
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/end-user-privacy-terms" target="_self">
#             Privacy Policy
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-reviewers/end-user-terms-and-conditions" target="_self">
#             Terms &amp; Conditions
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-reviewers/guidelines-for-reviewers" target="_self">
#             Guidelines for Reviewers
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://status.trustpilot.com/" target="_self">
#             System status
#            </a>
#           </li>
#           <li>
#            <a class="link_internal__7XN06 typography_body-m__xgxZ_ typography_appearance-default__AAY17 link_link__IZzHN link_notUnderlined__szqki footer-link_footerLink__9LkR_" href="https://legal.trustpilot.com/for-everyone/modern-slavery-and-human-trafficking-statement" target="_self">
#             Modern Slavery Statement
#            </a>
#           </li>
#          </ul>
#          <div class="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l footer_copyrightNotice__hiLk8">
#           © 2023 Trustpilot, Inc. All rights reserved.
#          </div>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" nonce="XDmssLsQj98e3ouF6hySoLJZewKgX6Yw9TaYZ2cnR0E=" type="application/json">
#    {"props":{"pageProps":{"pageUrl":"https://www.trustpilot.com/categories/fitness_and_nutrition_service?page=2","popularCategories":[],"newestBusinessUnits":[{"businessUnitId":"63f0fef431f80c12b6cda46c","displayName":"Plan Prehrane","identifyingName":"planprehrane.hr","stars":4,"trustScore":4.2,"numberOfReviews":6,"location":{"city":"Zagreb","country":"Croatia"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63d8ea70ca6109a9f0b9657e","displayName":"Athleteselement","identifyingName":"athleteselement.dk","stars":4.5,"trustScore":4.6,"numberOfReviews":18,"location":{"city":".","country":"Denmark"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63ef7de0e08cfbfd9da8cf89","displayName":"JRW Fitness","identifyingName":"www.jrwfitness.com","stars":4.5,"trustScore":4.4,"numberOfReviews":10,"location":{"city":"London","country":"United Kingdom"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63cc76f57ec124282d1889f2","displayName":"Holistic Cooking Classes","identifyingName":"holisticcookingclasses.com","stars":3.5,"trustScore":3.7,"numberOfReviews":1,"location":{"city":"","country":"United States"},"categories":[{"categoryId":"health_consultant","displayName":"Health Consultant","isPredicted":false},{"categoryId":"cooking_school","displayName":"Cooking School","isPredicted":false},{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false},{"categoryId":"cooking_class","displayName":"Cooking Class","isPredicted":false}]},{"businessUnitId":"63d2b6627461755f11b7264e","displayName":"P.D. Mangan 1-on-1 Coaching","identifyingName":"pdmangancoaching.com","stars":4.5,"trustScore":4.5,"numberOfReviews":14,"location":{"city":"St. Petersburg","country":"United States"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63f3a7a59a9702b032a40010","displayName":"Ronak Vora","identifyingName":"ronakvora.in","stars":4,"trustScore":4.1,"numberOfReviews":7,"location":{"city":"","country":"India"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false},{"categoryId":"physical_fitness_program","displayName":"Physical Fitness Program","isPredicted":false},{"categoryId":"health_consultant","displayName":"Health Consultant","isPredicted":false},{"categoryId":"life_coach","displayName":"Life Coach","isPredicted":false}]},{"businessUnitId":"640d0d6da1a5464aeb00b303","displayName":"High Exposure","identifyingName":"highexposurenutrition.com","stars":3.5,"trustScore":3.7,"numberOfReviews":1,"location":{"city":"Truckee","country":"United States"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63f9d2104493539d7dc7e0b2","displayName":"Modern Athlete Strength ","identifyingName":"modernathletestrength.com","stars":4,"trustScore":4.1,"numberOfReviews":5,"location":{"city":"Clarksville","country":"United States"},"categories":[{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness and Nutrition Service","isPredicted":false}]},{"businessUnitId":"63e7cc466e7b78a3eb77576a","displayName":"Hello Happy Nest - Food \u0026 Health Coaching","identifyingName":"hellohappynest.com","stars":3.5,"trustScore":3.7,"numberOfReviews":1,"location":{"city":"San Luis Obispo","country":"United States"},"categories":[{"categoryId":"wellness_program","displayName":"Wellness Program","isPredicted":false},{"categoryId":"weight_loss_service","displayName":"Weight Loss Service","isPredicted":false},{"categoryId":"fitness_and_nutrition_service","displayName":"Fitness ...
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## CONSIDERING THE WHOLE CONTAINER

# %%
company=soup.find_all('div',class_="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2")

# %%
len(company)
# Out:
# 20

# %%
name=[]
rating=[]
reviews=[]
location=[]
fitness_type=[]
for i in company:
#     try:
#         print(i.find('p',class_="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2").text.strip())
        print(i.find('span',class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ").text.strip())
#         print(i.find('p',class_='typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7').text.strip())
#         print(i.find('span',class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0").text.strip())
#     except:
#         print("NA")
        
#     print(i.find('div',class_='styles_wrapper___E6__ styles_categoriesLabels__FiWQ4 styles_desktop__U5iWw').text.strip())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [53], in <cell line: 6>()
#       5 fitness_type=[]
#       6 for i in company:
#       7 #     try:
#       8 #         print(i.find('p',class_="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2").text.strip())
# ----> 9         print(i.find('span',class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ").text.strip())
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
final=pd.DataFrame()
for j in range(1,28):
    headers={'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5)AppleWebKit/605.1.15 (KHTML, like Gecko)Version/12.1.1 Safari/605.1.15'}
    webpage = requests.get('https://www.trustpilot.com/categories/fitness_and_nutrition_service?page={}'.format(j), headers= headers).text
    soup=BeautifulSoup(webpage,'lxml')
    company=soup.find_all('div',class_="paper_paper__1PY90 paper_outline__lwsUX card_card__lQWDv card_noPadding__D8PcU styles_wrapper__2JOo2")
    name=[]
    rating=[]
    reviews=[]
    location=[]
    fitness_type=[]
    for i in company:
        try:
            name.append(i.find('p',class_="typography_heading-xs__jSwUz typography_appearance-default__AAY17 styles_displayName__GOhL2").text.strip())
        except:
            name.append(np.nan)
        try:
            rating.append(i.find('span',class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_trustScore__8emxJ").text.strip())
        except:
            rating.append(np.nan)
        try:
            reviews.append(i.find('p',class_='typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_ratingText__yQ5S7').text.strip())
        except:
            reviews.append(np.nan)
        try:
            location.append(i.find('span',class_="typography_body-m__xgxZ_ typography_appearance-subtle__8_H2l styles_metadataItem__Qn_Q2 styles_location__ILZb0").text.strip())
        except:
            location.append(np.nan)
        try:
            fitness_type.append(i.find('div',class_='styles_wrapper___E6__ styles_categoriesLabels__FiWQ4 styles_desktop__U5iWw').text.strip())
        except:
            fitness_type.append(np.nan)
            
    df=pd.DataFrame({'name':name,
                     'Rating':rating,
                     'Reviews':reviews,
                     'Location':location,
                     'Fitness':fitness_type,
                    })
    final=final.append(df,ignore_index=True)
# Out:
# C:\Users\varva\AppData\Local\Temp\ipykernel_616\3316170888.py:40: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
final.isna().sum()
# Out:
# name          0
# Rating      112
# Reviews     112
# Location    166
# Fitness       0
# dtype: int64

# %%
df=final

# %%
final.head()
# Out:
#                 name Rating                       Reviews  \
# 0  Better Way Health    4.9  TrustScore 4.9|3,930 reviews
# 1            Caliber    4.9    TrustScore 4.9|314 reviews
# 2     Basement Beast    4.9    TrustScore 4.9|266 reviews
# 3     Great CBD Shop    4.8  TrustScore 4.8|2,514 reviews
# 4      Flat Tummy Co    4.8  TrustScore 4.8|1,380 reviews
#
#                      Location  \
# 0     Kennesaw, United States
# 1     New York, United States
# 2                         NaN
# 3  Spartanubrg, United States
# 4                         NaN
#
#                                              Fitness
# 0  Herb Shop·Fitness and Nutrition Service·Vitami...
# 1  Fitness and Nutrition Service·Physical Fitness...
# 2  Fitness and Nutrition Service·Home Health Care...
# 3  Fitness and Nutrition Service·Herb Shop·Vitami...
# 4             Fitness and Nutrition Service·Pharmacy

# %%
df["Rating"]=df["Rating"].str.replace("TrustScore","")

# %%
df["Rating"]
# Out:
# 0       4.9
# 1       4.9
# 2       4.9
# 3       4.8
# 4       4.8
#        ...
# 534     NaN
# 535     NaN
# 536     NaN
# 537     NaN
# 538     NaN
# Name: Rating, Length: 539, dtype: object

# %%
start, stop, step = 15, -1, 1
df["Reviews"]=df["Reviews"].str.slice(start, stop, step)

# %%
df
# Out:
#                   name Rating       Reviews                    Location  \
# 0    Better Way Health    4.9  3,930 review     Kennesaw, United States
# 1              Caliber    4.9    314 review     New York, United States
# 2       Basement Beast    4.9    266 review                         NaN
# 3       Great CBD Shop    4.8  2,514 review  Spartanubrg, United States
# 4        Flat Tummy Co    4.8  1,380 review                         NaN
# ..                 ...    ...           ...                         ...
# 534      Alta Coaching    NaN           NaN   Sacramento, United States
# 535      Not One Rival    NaN           NaN   Georgetown, United States
# 536      macrosinc.net    NaN           NaN                         NaN
# 537     Free Your GOAT    NaN           NaN                         NaN
# 538           nucurate    NaN           NaN     New York, United States
#
#                                                Fitness
# 0    Herb Shop·Fitness and Nutrition Service·Vitami...
# 1    Fitness and Nutrition Service·Physical Fitness...
# 2    Fitness and Nutrition Service·Home Health Care...
# 3    Fitness and Nutrition Service·Herb Shop·Vitami...
# 4               Fitness and Nutrition Service·Pharmacy
# ..                                                 ...
# 534                      Fitness and Nutrition Service
# 535                      Fitness and Nutrition Service
# 536  Personal Trainer·Fitness and Nutrition Service...
# 537  Mental Health Service·Fitness and Nutrition Se...
# 538                      Fitness and Nutrition Service
#
# [539 rows x 5 columns]

# %%
df[["City","Country","Drop"]]=df["Location"].str.split(',',expand=True)

# %%
df.tail(50)
# Out:
#                                                name Rating Reviews  \
# 489                                  Fit With Grant    NaN     NaN
# 490                        BLUE GYM action wellness    NaN     NaN
# 491                                     Velobiotics    NaN     NaN
# 492                       brutestrengthtraining.com    NaN     NaN
# 493                                Genesis Physique    NaN     NaN
# 494                          Teixeira MMA & Fitness    NaN     NaN
# 495                              Remedy Well Health    NaN     NaN
# 496      TodWickersham.com / Beneficial Results LLC    NaN     NaN
# 497                                      Autumn DNA    NaN     NaN
# 498                               Athlete Boulevard    NaN     NaN
# 499                       TUF-TheUnbreakableFitness    NaN     NaN
# 500                                          MesoRx    NaN     NaN
# 501                        Primal Zest Health Coach    NaN     NaN
# 502                                goketogenics.com    NaN     NaN
# 503                       Bodyworks For Your Health    NaN     NaN
# 504                          Sand and Steel Fitness    NaN     NaN
# 505                                       Ablhealth    NaN     NaN
# 506                                        Smur Fit    NaN     NaN
# 507                            smarthealthclubs.com    NaN     NaN
# 508                                 Exos Works, Inc    NaN     NaN
# 509                                Spark Membership    NaN     NaN
# 510                                         Lullcbd    NaN     NaN
# 511                                    Purduepharma    NaN     NaN
# 512                      BG Healing Arts Apothecary    NaN     NaN
# 513  Buy Maxican Xanax Bars Online PayPal Overnight    NaN     NaN
# 514                                 Dore Health Ltd    NaN     NaN
# 515                                   Prescribe FIT    NaN     NaN
# 516                                 Better at Beach    NaN     NaN
# 517                             movewithpurpose.com    NaN     NaN
# 518                            findahealthcoach.com    NaN     NaN
# 519                                     21 Day Hero    NaN     NaN
# 520                            Gabrielle O'Hare LTD    NaN     NaN
# 521               Chioma Okafor-Mbah Gomez, MD PLLC    NaN     NaN
# 522       Ultimate Meal Plans - Custom Meal Planner    NaN     NaN
# 523                               Super Supplements    NaN     NaN
# 524                                           Honin    NaN     NaN
# 525                                          Bookee    NaN     NaN
# 526                                     WellnessEGO    NaN     NaN
# 527                                  KUSH HOUSE ATX    NaN     NaN
# 528                                    Asappfitness    NaN     NaN
# 529                            The Nutrition Clinic    NaN     NaN
# 530                           Personal Best Program    NaN     NaN
# 531                                       Fitillion    NaN     NaN
# 532                                         Jaguara    NaN     NaN
# 533                                     MNML Health    NaN     NaN
# 534                                   Alta Coaching    NaN     NaN
# 535                                   Not One Rival    NaN     NaN
# 536                                   macrosinc.net    NaN     NaN
# 537                                  Free Your GOAT    NaN     NaN
# 538                                        nucurate    NaN     NaN
#
#                          Location  \
# 489     Georgetown, United States
# 490      Peristeri, United States
# 491      Germiston, United States
# 492                           NaN
# 493                           NaN
# 494         Bethel, United States
# 495                           NaN
# 496        Madison, United States
# 497      San Diego, United States
# 498       Sheridan, United States
# 499                           NaN
# 500                           NaN
# 501                           NaN
# 502             NY, United States
# 503       New York, United States
# 504     Alexandria, United States
# 505                           NaN
# 506                           NaN
# 507         Irvine, United States
# 508        Phoenix, United States
# 509        Florida, United States
# 510                           NaN
# 511                           NaN
# 512  Battle Ground, United States
# 513       New York, United States
# 514                           NaN
# 515                           NaN
# 516                           NaN
# 517   Grand Rapids, United States
# 518         Conroe, United States
# 519                           NaN
# 520                           NaN
# 521             NY, United States
# 522                           NaN
# 523        Hialeah, United States
# 524                           NaN
# 525         Covina, United States
# 526        Potomac, United States
# 527  Austin, Texas, United States
# 528                           NaN
# 529  Port St Lucie, United States
# 530      Helendale, United States
# 531                           NaN
# 532                           NaN
# 533    Los Angeles, United States
# 534     Sacramento, United States
# 535     Georgetown, United States
# 536                           NaN
# 537                           NaN
# 538       New York, United States
#
#                                                Fitness           City  \
# 489  Fitness and Nutrition Service·Physical Fitness...     Georgetown
# 490  Class·Weight Loss Service·Fitness and Nutritio...      Peristeri
# 491  Fitness and Nutrition Service·Vitamin and Supp...      Germiston
# 492  Fitness and Nutrition Service·Gymnastics Cente...            NaN
# 493  Fitness and Nutrition Service·Physical Fitness...            NaN
# 494  Jujitsu School·Mixed Martial Arts Club·Fitness...         Bethel
# 495  Wellness Program·Medical Group·General Practit...            NaN
# 496  Nutritionist·Health Consultant·Fitness and Nut...        Madison
# 497  Diagnostic Center·Fitness and Nutrition Servic...      San Diego
# 498  Sports Nutrition Store·Vitamin and Supplements...       Sheridan
# 499  Fitness and Nutrition Service·Physical Fitness...            NaN
# 500                      Fitness and Nutrition Service            NaN
# 501  Fitness and Nutrition Service·Wellness Program...            NaN
# 502  Fitness and Nutrition Service·Health Food Stor...             NY
# 503  Wellness Center·Fitness and Nutrition Service·...       New York
# 504  Fitness and Nutrition Service·Weight Loss Serv...     Alexandria
# 505  Mental Health Service·Community Health Centre·...            NaN
# 506  Fitness and Nutrition Service·Personal Trainer...            NaN
# 507      Software Vendor·Fitness and Nutrition Service         Irvine
# 508  Fitness Center·Wellness Program·Fitness and Nu...        Phoenix
# 509  Fitness and Nutrition Service·Software Vendor·...        Florida
# 510  Fitness and Nutrition Service·Vitamin and Supp...            NaN
# 511  Health and Beauty Shop·Health Consultant·Fitne...            NaN
# 512  Fitness and Nutrition Service·Alternative Medi...  Battle Ground
# 513  Pharmacy·Fitness and Nutrition Service·Mental ...       New York
# 514  Personal Trainer·Fitness and Nutrition Service...            NaN
# 515  Weight Loss Service·Fitness and Nutrition Serv...            NaN
# 516  Physical Fitness Program·Beach Volleyball Club...            NaN
# 517  Yoga Instructor·Gym·Fitness and Nutrition Serv...   Grand Rapids
# 518  Online Marketing Agency·Media Company·Fitness ...         Conroe
# 519    Health Consultant·Fitness and Nutrition Service            NaN
# 520  Fitness and Nutrition Service·Publisher·Women'...            NaN
# 521  Medical Spa·Family Practice Physician·Weight L...             NY
# 522  Health and Beauty Shop·Fitness and Nutrition S...            NaN
# 523                      Fitness and Nutrition Service        Hialeah
# 524  Wellness Program·Fitness and Nutrition Service...            NaN
# 525     Fitness and Nutrition Service·Software Company         Covina
# 526                      Fitness and Nutrition Service        Potomac
# 527                      Fitness and Nutrition Service         Austin
# 528  Personal Trainer·Fitness and Nutrition Service...            NaN
# 529  Weight Loss Service·Diabetes Center·Health Con...  Port St Lucie
# 530                      Fitness and Nutrition Service      Helendale
# 531                      Fitness and Nutrition Service            NaN
# 532                      Fitness and Nutrition Service            NaN
# 533                      Fitness and Nutrition Service    Los Angeles
# 534                      Fitness and Nutrition Service     Sacramento
# 535                      Fitness and Nutrition Service     Georgetown
# 536  Personal Trainer·Fitness and Nutrition Service...            NaN
# 537  Mental Health Service·Fitness and Nutrition Se...            NaN
# 538                      Fitness and Nutrition Service       New York
#
#             Country
# 489   United States
# 490   United States
# 491   United States
# 492             NaN
# 493             NaN
# 494   United States
# 495             NaN
# 496   United States
# 497   United States
# 498   United States
# 499             NaN
# 500             NaN
# 501             NaN
# 502   United States
# 503   United States
# 504   United States
# 505             NaN
# 506             NaN
# 507   United States
# 508   United States
# 509   United States
# 510             NaN
# 511             NaN
# 512   United States
# 513   United States
# 514             NaN
# 515             NaN
# 516             NaN
# 517   United States
# 518   United States
# 519             NaN
# 520             NaN
# 521   United States
# 522             NaN
# 523   United States
# 524             NaN
# 525   United States
# 526   United States
# 527           Texas
# 528             NaN
# 529   United States
# 530   United States
# 531             NaN
# 532             NaN
# 533   United States
# 534   United States
# 535   United States
# 536             NaN
# 537             NaN
# 538   United States

# %%
df.drop(["Drop"],axis=1,inplace=True)

# %%
df
# Out:
#                   name Rating       Reviews                    Location  \
# 0    Better Way Health    4.9  3,930 review     Kennesaw, United States
# 1              Caliber    4.9    314 review     New York, United States
# 2       Basement Beast    4.9    266 review                         NaN
# 3       Great CBD Shop    4.8  2,514 review  Spartanubrg, United States
# 4        Flat Tummy Co    4.8  1,380 review                         NaN
# ..                 ...    ...           ...                         ...
# 534      Alta Coaching    NaN           NaN   Sacramento, United States
# 535      Not One Rival    NaN           NaN   Georgetown, United States
# 536      macrosinc.net    NaN           NaN                         NaN
# 537     Free Your GOAT    NaN           NaN                         NaN
# 538           nucurate    NaN           NaN     New York, United States
#
#                                                Fitness         City  \
# 0    Herb Shop·Fitness and Nutrition Service·Vitami...     Kennesaw
# 1    Fitness and Nutrition Service·Physical Fitness...     New York
# 2    Fitness and Nutrition Service·Home Health Care...          NaN
# 3    Fitness and Nutrition Service·Herb Shop·Vitami...  Spartanubrg
# 4               Fitness and Nutrition Service·Pharmacy          NaN
# ..                                                 ...          ...
# 534                      Fitness and Nutrition Service   Sacramento
# 535                      Fitness and Nutrition Service   Georgetown
# 536  Personal Trainer·Fitness and Nutrition Service...          NaN
# 537  Mental Health Service·Fitness and Nutrition Se...          NaN
# 538                      Fitness and Nutrition Service     New York
#
#             Country
# 0     United States
# 1     United States
# 2               NaN
# 3     United States
# 4               NaN
# ..              ...
# 534   United States
# 535   United States
# 536             NaN
# 537             NaN
# 538   United States
#
# [539 rows x 7 columns]
