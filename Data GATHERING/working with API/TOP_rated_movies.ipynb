# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=d6b1a099bda1474091bbbea7a1a70562&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','adult','title','overview','release_date','popularity','vote_average','vote_count']]
temp_df.head()
# Out:
#        id  adult                     title  \
# 0     238  False             The Godfather
# 1     278  False  The Shawshank Redemption
# 2  772071  False          Cuando Sea Joven
# 3     240  False     The Godfather Part II
# 4     424  False          Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      96.651
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      85.375
# 2  70-year-old Malena gets a second chance at lif...   2022-09-14      42.078
# 3  In the continuing saga of the Corleone crime f...   1974-12-20      65.080
# 4  The true story of how businessman Oskar Schind...   1993-12-15      52.225
#
#    vote_average  vote_count
# 0           8.7       17654
# 1           8.7       23496
# 2           8.6         212
# 3           8.6       10698
# 4           8.6       13894

# %%
temp_df.shape
# Out:
# (20, 8)

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range( 10926):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','adult','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
#       1 for i in range( 10926):
#       2     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
# ----> 3     temp_df = pd.DataFrame(response.json()['results'])[['id','adult','title','overview','release_date','popularity','vote_average','vote_count']]
#       4     df = df.append(temp_df,ignore_index=True)
#
# KeyError: 'results'

# %%
for i in range(1,547):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\varva\AppData\Local\Temp\ipykernel_8020\2681369366.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\varva\AppData\Local\Temp\ipykernel_8020\2681369366.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\varva\AppData\Local\Temp\ipykernel_8020\2681369366.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\varva\AppData\Local\Temp\ipykernel_8020\2681369366.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...

# %%
df.head()
# Out:
#        id                     title  \
# 0     238             The Godfather
# 1     278  The Shawshank Redemption
# 2  772071          Cuando Sea Joven
# 3     240     The Godfather Part II
# 4     424          Schindler's List
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      96.651
# 1  Framed in the 1940s for the double murder of h...   1994-09-23      85.375
# 2  70-year-old Malena gets a second chance at lif...   2022-09-14      42.078
# 3  In the continuing saga of the Corleone crime f...   1974-12-20      65.080
# 4  The true story of how businessman Oskar Schind...   1993-12-15      52.225
#
#    vote_average  vote_count
# 0           8.7       17654
# 1           8.7       23496
# 2           8.6         212
# 3           8.6       10698
# 4           8.6       13894

# %%
df.shape
# Out:
# (19060, 7)

# %%
df.to_csv("top_rated_movies")
